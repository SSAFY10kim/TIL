# %%
# 필요 패키지 import
import pprint
import requests

# %% [markdown]
# # 문제3. 응답 중 정기예금 상품들의 옵션 리스트를 출력하도록 구성합니다.
# ##  이 때, 원하는 데이터만 추출하여 새로운 리스트를 만들어 반환하는 함수를 작성하시오.
# - [힌트] 아래와 같은 순서로 데이터를 출력하며 진행합니다.
# - 1. 응답을 json 형식으로 변환합니다.
# - 2. key 값이 "result" 인 데이터를 출력합니다.
# - 3. 위의 결과 중 key 값이 "optionList" 인 데이터를 변수에 저장합니다.
# - 4. 3번에서 저장된 값을 반복하며, 원하는 데이터만 추출 및 가공하여 결과 리스트에 저장합니다.

# %%
def get_deposit_product():
    api_key = "957d9a90c722f26f20d21e7fbbefeab1"

    url = f'http://finlife.fss.or.kr/finlifeapi/depositProductsSearch.json'
    params = {
        'auth' : api_key,
        # 금융회사 코드 ---
        'topFinGrpNo' : '020000',
        'pageNo' : 1
    }

    # 응답을 json 형태로 변환
    response = requests.get(url, params=params).json()
    term_deposit = response["result"]
    
    whole_new_option_list = []
    for i in range(term_deposit["total_count"]):
        new_option_list = {}
        new_option_list["금융상품코드"] = term_deposit["optionList"][i]["fin_prdt_cd"]
        new_option_list["저축 금리"] =  term_deposit["optionList"][i]["intr_rate"]
        new_option_list["저축 기간"] = term_deposit["optionList"][i]["save_trm"]
        new_option_list["저축금리유형"] = term_deposit["optionList"][i]["intr_rate_type"]
        new_option_list["저축금리유형명"] = term_deposit["optionList"][i]["intr_rate_type_nm"]
        new_option_list["최고 우대금리"] = term_deposit["optionList"][i]["intr_rate2"]
        whole_new_option_list.append(new_option_list)
    return whole_new_option_list

# %%
# 아래 코드는 수정하지 않습니다.
if __name__ == '__main__':
    # json 형태의 데이터 반환
    result = get_deposit_product()
    # prrint.prrint(): json 을 보기 좋은 형식으로 출력
    pprint.pprint(result)
# Out:
# [{'금융상품코드': 'WR0001B',
#   '저축 금리': 3.67,
#   '저축 기간': '6',
#   '저축금리유형': 'S',
#   '저축금리유형명': '단리',
#   '최고 우대금리': 3.67},
#  {'금융상품코드': 'WR0001B',
#   '저축 금리': 3.73,
#   '저축 기간': '12',
#   '저축금리유형': 'S',
#   '저축금리유형명': '단리',
#   '최고 우대금리': 3.73},
#  {'금융상품코드': 'WR0001B',
#   '저축 금리': 3.36,
#   '저축 기간': '24',
#   '저축금리유형': 'S',
#   '저축금리유형명': '단리',
#   '최고 우대금리': 3.36},
#  {'금융상품코드': 'WR0001B',
#   '저축 금리': 3.33,
#   '저축 기간': '36',
#   '저축금리유형': 'S',
#   '저축금리유형명': '단리',
#   '최고 우대금리': 3.33},
#  {'금융상품코드': '00320342',
#   '저축 금리': 3.7,
#   '저축 기간': '6',
#   '저축금리유형': 'S',
#   '저축금리유형명': '단리',
#   '최고 우대금리': 3.9},
#  {'금융상품코드': '00320342',
#   '저축 금리': 3.9,
#   '저축 기간': '12',
#   '저축금리유형': 'S',
#   '저축금리유형명': '단리',
#   '최고 우대금리': 4.2},
#  {'금융상품코드': '10511008000996000',
#   '저축 금리': 2.46,
#   '저축 기간': '6',
#   '저축금리유형': 'S',
#   '저축금리유형명': '단리',
#   '최고 우대금리': 3.11},
#  {'금융상품코드': '10511008000996000',
#   '저축 금리': 3.2,
#   '저축 기간': '12',
#   '저축금리유형': 'S',
#   '저축금리유형명': '단리',
# ...
